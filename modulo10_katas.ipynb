# %% [markdown]
# ### Tracebacks

# %%
def main():
    open("/path/to/mars.jpg")

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Controlando las excepciones

# %%
def main():
    try:
        configuration = open('config.txt')
    except Exception:
        print("No se pudo encontrar el archivo config.txt")

if __name__ == '__main__':
    main()
# Out:
# No se pudo encontrar el archivo config.txt

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("No se pudo encontrar el archivo config.txt")
    except IsADirectoryError:
        print("Se encontro config.txt pero es un directorio, no se puede leer")
    #Se agregó otro tipo de excepción
    except PermissionError:
        print("No tienes permisos para abrir el directorio")

if __name__ == '__main__':
    main()
# Out:
# No tienes permisos para abrir el directorio

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("No se pudo encontrar el archivo config.txt")
    except IsADirectoryError:
        print("Se encontro config.txt pero es un directorio, no se puede leer")
    #Se agregó otro tipo de excepción
    except PermissionError:
        print("No tienes permisos para abrir el directorio")
    except (BlockingIOError, TimeoutError):
        print("Sistema de archivos bajo mucha carga, no se puede completar la lectura del archivo de configuración")

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Generación de excepciones

# %%
def aguaRestante(astronautas, aguaRestante, diasRestantes):
    usoDiario = astronautas * 11
    usoTotal = usoDiario * diasRestantes
    totalAguaRestante = aguaRestante - usoTotal
    return f"El agua restante despues de {diasRestantes} dias es: {totalAguaRestante} litros"

aguaRestante(5, 100, 2)
# Out:
# 'El agua restante despues de 2 dias es: -10 litros'

# %%
def aguaRestante(astronautas, aguaRestante, diasRestantes):
    usoDiario = astronautas * 11
    usoTotal = usoDiario * diasRestantes
    totalAguaRestante = aguaRestante - usoTotal
    
    if totalAguaRestante < 0:
        raise RuntimeError(f"No hay agua suficiente para {astronautas} astronautas despues de {diasRestantes} dias")
    return f"El agua restante despues de {diasRestantes} dias es: {totalAguaRestante} litros"

aguaRestante(5, 100, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\Israel-PC\Desktop\LaunchX\Katas resueltas\modulo10_katasUntitled-1.ipynb Cell 10' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Israel-PC/Desktop/LaunchX/Katas%20resueltas/modulo10_katasUntitled-1.ipynb#ch0000010?line=6'>7</a>         raise RuntimeError(f"No hay agua suficiente para {astronautas} astronautas despues de {diasRestantes} dias")
#       <a href='vscode-notebook-cell:/c%3A/Users/Israel-PC/Desktop/LaunchX/Katas%20resueltas/modulo10_katasUntitled-1.ipynb#ch0000010?line=7'>8</a>     return f"El agua restante despues de {diasRestantes} dias es: {totalAguaRestante} litros"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Israel-PC/Desktop/LaunchX/Katas%20resueltas/modulo10_katasUntitled-1.ipynb#ch0000010?line=9'>10</a> aguaRestante(5, 100, 2)
#
# ...

# %%
def aguaRestante(astronautas, aguaRestante, diasRestantes):
    usoDiario = astronautas * 11
    usoTotal = usoDiario * diasRestantes
    totalAguaRestante = aguaRestante - usoTotal
    
    if totalAguaRestante < 0:
        raise RuntimeError(f"No hay agua suficiente para {astronautas} astronautas despues de {diasRestantes} dias")
    return f"El agua restante despues de {diasRestantes} dias es: {totalAguaRestante} litros"

try:
    aguaRestante(5, 100, 2)
except RuntimeError as err:
    alert_navigation_system(err)

# %%
def aguaRestante(astronautas, aguaRestante, diasRestantes):
    for argumento in [astronautas, aguaRestante, diasRestantes]:
        try:
            argumento / 10
        except TypeError:
            raise TypeError(f"All arguments must be of type int, but received: '{argumento}'")
    usoDiario = astronautas * 11
    usoTotal = usoDiario * diasRestantes
    totalAguaRestante = aguaRestante - usoTotal
    if totalAguaRestante < 0:
        raise RuntimeError(f"No hay agua suficiente para {astronautas} astronautas despues de {diasRestantes} dias")
    return f"El agua restante despues de {diasRestantes} dias es: {totalAguaRestante} litros"

aguaRestante("3", "200", None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Israel-PC\Desktop\LaunchX\Katas resueltas\modulo10_katasUntitled-1.ipynb Cell 12' in aguaRestante(astronautas, aguaRestante, diasRestantes)
#       <a href='vscode-notebook-cell:/c%3A/Users/Israel-PC/Desktop/LaunchX/Katas%20resueltas/modulo10_katasUntitled-1.ipynb#ch0000012?line=2'>3</a> try:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Israel-PC/Desktop/LaunchX/Katas%20resueltas/modulo10_katasUntitled-1.ipynb#ch0000012?line=3'>4</a>     argumento / 10
#       <a href='vscode-notebook-cell:/c%3A/Users/Israel-PC/Desktop/LaunchX/Katas%20resueltas/modulo10_katasUntitled-1.ipynb#ch0000012?line=4'>5</a> except TypeError:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# ...

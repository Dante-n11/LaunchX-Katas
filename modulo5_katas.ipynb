# %% [markdown]
# # Ejercicio 1: Usar operadores aritmeticos

# %%
from math import ceil

tierra = 149597870
jupiter = 778547200

distanciaEntrePla = jupiter - tierra
print (distanciaEntrePla)

distanciaConv = distanciaEntrePla * 0.621
print(distanciaConv)
# Out:
# 628949330
# 390577533.93

# %% [markdown]
# # Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %%
from math import ceil

distancia1 = int (input('Ingresa la distancia al sol del primer planeta'))
distancia2 = int (input('Ingresa la distancia al sol del segundo planeta'))

distanciaEnKm =  distancia1 - distancia2
print (abs(distanciaEnKm))

distanciaEnMi = distanciaEnKm * 0.621
print(abs(distanciaEnMi))
# Out:
# 50
# 31.05
